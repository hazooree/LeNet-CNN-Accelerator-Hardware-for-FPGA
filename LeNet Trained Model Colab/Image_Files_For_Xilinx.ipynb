# %% [markdown]
# # Image Files for Xilinx

# %%
from keras.models import Sequential, load_model # type of model 
from keras.layers import Dense, Activation, Conv2D,MaxPooling2D, Dropout, Flatten
from keras.optimizers import sgd, Adadelta
from keras.datasets import mnist
from keras.losses import categorical_crossentropy
from keras.utils import to_categorical
import numpy as np
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test  = x_test.reshape(x_test.shape[0], 28, 28, 1)
x_train = x_train.astype('float32')
x_test  = x_test.astype('float32')
x_train = x_train/255
x_test  = x_test/255
y_train = to_categorical(y_train,10)
y_test  = to_categorical(y_test ,10)

# %%
I0 = x_train[1].reshape((28,28));
I0t= x_train[1].reshape((28,28)).T;
I1 = x_train[3].reshape((28,28));
I1t= x_train[3].reshape((28,28)).T;
I2 = x_train[5].reshape((28,28));
I2t= x_train[5].reshape((28,28)).T;
I3 = x_train[7].reshape((28,28));
I3t= x_train[7].reshape((28,28)).T;
I4 = x_train[2].reshape((28,28));
I4t= x_train[2].reshape((28,28)).T;
I5 = x_train[0].reshape((28,28));
I5t= x_train[0].reshape((28,28)).T;
I6 = x_train[13].reshape((28,28));
I6t= x_train[13].reshape((28,28)).T;
I7 = x_train[15].reshape((28,28));
I7t= x_train[15].reshape((28,28)).T;
I8 = x_train[17].reshape((28,28));
I8t= x_train[17].reshape((28,28)).T;
I9 = x_train[4].reshape((28,28));
I9t= x_train[4].reshape((28,28)).T;
N = 28;
K = 28;

# %% [markdown]
# # Zero

# %%
I = I0;
fig = plt.imshow(I,cmap='gray')
ax = plt.gca()
ax.set_xticks([])
ax.set_yticks([])
# Out:
# []

# %%
#for i in range(0 , N):
#  for j in range(0 , K):
#    print(I[i][j])
for i in range(0 , N):
  for j in range(0 , K):
    if (int(256*I[i][j])>=0):
      print ('{:032b}'.format(int(256*I[i][j])))
    else:
      print ('{:032b}'.format(4294967296+int(256*I[i][j])))
# Out:
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# ...

# %% [markdown]
# # One

# %%
I = I1;
imgplot = plt.imshow(I,cmap='gray')
ax = plt.gca()
ax.set_xticks([])
ax.set_yticks([])
# Out:
# []

# %%
#for i in range(0 , N):
#  for j in range(0 , K):
#   print(I[i][j])
for i in range(0 , N):
  for j in range(0 , K):
    if (int(256*I[i][j])>=0):
      print ('{:032b}'.format(int(256*I[i][j])))
    else:
      print ('{:032b}'.format(4294967296+int(256*I[i][j])))
# Out:
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# ...

# %% [markdown]
# # Two

# %%
I = I2;
imgplot = plt.imshow(I,cmap='gray')
ax = plt.gca()
ax.set_xticks([])
ax.set_yticks([])
# Out:
# []

# %%
#for i in range(0 , N):
#  for j in range(0 , K):
#    print(I[i][j])
for i in range(0 , N):
  for j in range(0 , K):
    if (int(256*I[i][j])>=0):
      print ('{:032b}'.format(int(256*I[i][j])))
    else:
      print ('{:032b}'.format(4294967296+int(256*I[i][j])))
# Out:
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# ...

# %% [markdown]
# #Three

# %%
I = I3;
imgplot = plt.imshow(I,cmap='gray')
ax = plt.gca()
ax.set_xticks([])
ax.set_yticks([])
# Out:
# []

# %%
for i in range(0 , N):
  for j in range(0 , K):
    if (int(256*I[i][j])>=0):
      print ('{:032b}'.format(int(256*I[i][j])))
    else:
      print ('{:032b}'.format(4294967296+int(256*I[i][j])))
# Out:
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# ...

# %% [markdown]
# #Four

# %%
I = I4;
imgplot = plt.imshow(I,cmap='gray')
ax = plt.gca()
ax.set_xticks([])
ax.set_yticks([])
# Out:
# []

# %%
for i in range(0 , N):
  for j in range(0 , K):
    if (int(256*I[i][j])>=0):
      print ('{:032b}'.format(int(256*I[i][j])))
    else:
      print ('{:032b}'.format(4294967296+int(256*I[i][j])))
# Out:
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# ...

# %% [markdown]
# #Five

# %%
I = I5;
imgplot = plt.imshow(I,cmap='gray')
ax = plt.gca()
ax.set_xticks([])
ax.set_yticks([])
# Out:
# []

# %%
for i in range(0 , N):
  for j in range(0 , K):
    if (int(256*I[i][j])>=0):
      print ('{:032b}'.format(int(256*I[i][j])))
    else:
      print ('{:032b}'.format(4294967296+int(256*I[i][j])))
# Out:
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# ...

# %% [markdown]
# #Six

# %%
I = I6;
imgplot = plt.imshow(I,cmap='gray')
ax = plt.gca()
ax.set_xticks([])
ax.set_yticks([])
# Out:
# []

# %%
for i in range(0 , N):
  for j in range(0 , K):
    if (int(256*I[i][j])>=0):
      print ('{:032b}'.format(int(256*I[i][j])))
    else:
      print ('{:032b}'.format(4294967296+int(256*I[i][j])))
# Out:
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# ...

# %% [markdown]
# #Seven

# %%
I = I7;
imgplot = plt.imshow(I,cmap='gray')
ax = plt.gca()
ax.set_xticks([])
ax.set_yticks([])
# Out:
# []

# %%
for i in range(0 , N):
  for j in range(0 , K):
    if (int(256*I[i][j])>=0):
      print ('{:032b}'.format(int(256*I[i][j])))
    else:
      print ('{:032b}'.format(4294967296+int(256*I[i][j])))
# Out:
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# ...

# %% [markdown]
# #Eight

# %%
I = I8;
imgplot = plt.imshow(I,cmap='gray')
ax = plt.gca()
ax.set_xticks([])
ax.set_yticks([])
# Out:
# []

# %%
for i in range(0 , N):
  for j in range(0 , K):
    if (int(256*I[i][j])>=0):
      print ('{:032b}'.format(int(256*I[i][j])))
    else:
      print ('{:032b}'.format(4294967296+int(256*I[i][j])))
# Out:
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# ...

# %% [markdown]
# #Nine

# %%
I = I9;
imgplot = plt.imshow(I,cmap='gray')
ax = plt.gca()
ax.set_xticks([])
ax.set_yticks([])
# Out:
# []

# %%
for i in range(0 , N):
  for j in range(0 , K):
    if (int(256*I[i][j])>=0):
      print ('{:032b}'.format(int(256*I[i][j])))
    else:
      print ('{:032b}'.format(4294967296+int(256*I[i][j])))
# Out:
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# ...
